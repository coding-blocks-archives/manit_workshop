# %%
import os
import matplotlib.pyplot as plt

# %%
dataset_labels = "Pokemon/train.csv"

# %%
images_path = "Pokemon/Images/"

# %%
images = os.listdir(images_path)

# %%
img = plt.imread(images_path + images[0])

# %%
plt.imshow(img)

# %%
import pandas as pd
file = pd.read_csv(dataset_labels)

# %%
file.head()
# Out:
#    ImageId NameOfPokemon
# 0  296.jpg       Pikachu
# 1  297.jpg       Pikachu
# 2  298.jpg       Pikachu
# 3  299.jpg       Pikachu
# 4  300.jpg       Pikachu
